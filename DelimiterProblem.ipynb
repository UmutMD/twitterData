# %%
import pyspark
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import pyspark
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
import findspark
findspark.init()
findspark.find()
# Out:
# 'C:\\spark-3.3.0-bin-hadoop2'

# %%
import pyspark

# %% [markdown]
# from pyspark.sql import SparkSession
#
# spark = SparkSession.builder.appName("DataFrame").getOrCreate()
#
# df = spark.read.text("twitter_small.txt")
#
# df.selectExpr("split(value, ' | ') as\
# Text_Data_In_Rows_Using_Text").show(4,False)

# %%
from pyspark.sql import SparkSession

# %%
spark2= SparkSession.builder.getOrCreate()

# %%
import pyspark.sql.functions as f

# %%
df2 = spark2.read.option("header", "False")\
    .option("delimiter", ", ")\
    .option("ignoreLeadingWhiteSpace", "False")\
    .option("ignoreTrailingWhiteSpace","False")\
    .option("inferScheme", "True") \
    .csv("twitter_small.txt")

# %%
df2.show()
# Out:
# +--------------------+--------------------+
# |                 _c0|                 _c1|
# +--------------------+--------------------+
# |{"created_at": "F...|""id": 1266393580...|
# |{"created_at": "F...|""id": 1266393579...|
# |{"created_at": "F...|""id": 1266393579...|
# |{"created_at": "F...|""id": 1266393578...|
# |{"created_at": "F...|""id": 1266393578...|
# |{"created_at": "F...|""id": 1266393578...|
# |{"created_at": "F...|""id": 1266393577...|
# |{"created_at": "F...|""id": 1266393577...|
# |{"created_at": "F...|""id": 1266393575...|
# |{"created_at": "F...|""id": 1266393575...|
# |{"created_at": "F...|""id": 1266393575...|
# |{"created_at": "F...|""id": 1266393575...|
# |{"created_at": "F...|""id": 1266393575...|
# |{"created_at": "F...|""id": 1266393574...|
# |{"created_at": "F...|""id": 1266393574...|
# |{"created_at": "F...|""id": 1266393574...|
# |{"created_at": "F...|""id": 1266393574...|
# |{"created_at": "F...|""id": 1266393573...|
# |{"created_at": "F...|""id": 1266393573...|
# |{"created_at": "F...|""id": 1266393572...|
# +--------------------+--------------------+
# only showing top 20 rows

# %%
df2.printSchema()
# Out:
# root
#  |-- {"created_at": "Fri May 29 15:38:52 +0000 2020": string (nullable = true)
#  |--  "id": 1266393580223987713: string (nullable = true)
#  |--  "id_str": "1266393580223987713": string (nullable = true)
#  |--  "full_text": "RT @Desiree_Laverne: #MyBeautifulAfrica....\u2764\nAardwolf.. https://t.co/9C7MjkQaIp": string (nullable = true)
#  |--  "truncated": false4: string (nullable = true)
#  |--  "display_text_range": [05: string (nullable = true)
#  |--  79]6: string (nullable = true)
#  |--  "entities": {"hashtags": [{"text": "MyBeautifulAfrica"7: string (nullable = true)
#  |--  "indices": [21: string (nullable = true)
#  |--  39]}]: string (nullable = true)
#  |--  "symbols": []10: string (nullable = true)
#  |--  "user_mentions": [{"screen_name": "Desiree_Laverne": string (nullable = true)
#  |--  "name": "Desiree_Laverne"12: string (nullable = true)
#  |--  "id": 2314937901: string (nullable = true)
#  |--  "id_str": "2314937901"14: string (nullable = true)
#  |--  "indices": [3: string (nullable = true)
#  |--  19]}]: string (nullable = true)
#  |--  "urls": []17: string (nullable = true)
#  |--  "media": [{"id": 126628681731517645018: string (nullable = true)
#  |--  "id_str": "1266286817315176450"19: string (nullable = true)
#  |--  "indices": [5620: string (nullable = true)
#  |--  79]21: string (nullable = true)
#  |--  "media_url": "http://pbs.twimg.com/media/EZLBJrnUwAI9IbT.jpg"22: string (nullable = true)
#  |--  "media_url_https": "https://pbs.twimg.com/media/EZLBJrnUwAI9IbT.jpg"23: string (nullable = true)
#  |--  "url": "https://t.co/9C7MjkQaIp"24: string (nullable = true)
#  |--  "display_url": "pic.twitter.com/9C7MjkQaIp"25: string (nullable = true)
#  |--  "expanded_url": "https://twitter.com/Desiree_Laverne/status/1266286830116200448/photo/1"26: string (nullable = true)
#  |--  "type": "photo"27: string (nullable = true)
#  |--  "sizes": {"thumb": {"w": 15028: string (nullable = true)
#  |--  "h": 15029: string (nullable = true)
#  |--  "resize": "crop"}30: string (nullable = true)
#  |--  "large": {"w": 56431: string (nullable = true)
#  |--  "h": 43532: string (nullable = true)
#  |--  "resize": "fit"}33: string (nullable = true)
#  |--  "small": {"w": 56434: string (nullable = true)
#  |--  "h": 43535: string (nullable = true)
#  |--  "resize": "fit"}36: string (nullable = true)
#  |--  "medium": {"w": 56437: string (nullable = true)
#  |--  "h": 43538: string (nullable = true)
#  |--  "resize": "fit"}}39: string (nullable = true)
#  |--  "source_status_id": 126628683011620044840: string (nullable = true)
#  |--  "source_status_id_str": "1266286830116200448"41: string (nullable = true)
#  |--  "source_user_id": 231493790142: string (nullable = true)
#  |--  "source_user_id_str": "2314937901"}]}43: string (nullable = true)
#  |--  "extended_entities": {"media": [{"id": 126628681731517645044: string (nullable = true)
#  |--  "id_str": "1266286817315176450"45: string (nullable = true)
#  |--  "indices": [5646: string (nullable = true)
#  |--  79]47: string (nullable = true)
#  |--  "media_url": "http://pbs.twimg.com/media/EZLBJrnUwAI9IbT.jpg"48: string (nullable = true)
#  |--  "media_url_https": "https://pbs.twimg.com/media/EZLBJrnUwAI9IbT.jpg"49: string (nullable = true)
#  |--  "url": "https://t.co/9C7MjkQaIp"50: string (nullable = true)
#  |--  "display_url": "pic.twitter.com/9C7MjkQaIp"51: string (nullable = true)
#  |--  "expanded_url": "https://twitter.com/Desiree_Laverne/status/1266286830116200448/photo/1"52: string (nullable = true)
#  |--  "type": "photo"53: string (nullable = true)
#  |--  "sizes": {"thumb": {"w": 15054: string (nullable = true)
#  |--  "h": 15055: string (nullable = true)
#  |--  "resize": "crop"}56: string (nullable = true)
#  |--  "large": {"w": 56457: string (nullable = true)
#  |--  "h": 43558: string (nullable = true)
#  |--  "resize": "fit"}59: string (nullable = true)
#  |--  "small": {"w": 56460: string (nullable = true)
#  |--  "h": 43561: string (nullable = true)
#  |--  "resize": "fit"}62: string (nullable = true)
#  |--  "medium": {"w": 56463: string (nullable = true)
#  |--  "h": 43564: string (nullable = true)
#  |--  "resize": "fit"}}65: string (nullable = true)
#  |--  "source_status_id": 126628683011620044866: string (nullable = true)
#  |--  "source_status_id_str": "1266286830116200448"67: string (nullable = true)
#  |--  "source_user_id": 231493790168: string (nullable = true)
#  |--  "source_user_id_str": "2314937901"}]}69: string (nullable = true)
#  |--  "metadata": {"iso_language_code": "nl"70: string (nullable = true)
#  |--  "result_type": "recent"}71: string (nullable = true)
#  |--  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>"72: string (nullable = true)
#  |--  "in_reply_to_status_id": null73: string (nullable = true)
#  |--  "in_reply_to_status_id_str": null74: string (nullable = true)
#  |--  "in_reply_to_user_id": null75: string (nullable = true)
#  |--  "in_reply_to_user_id_str": null76: string (nullable = true)
#  |--  "in_reply_to_screen_name": null77: string (nullable = true)
#  |--  "user": {"id": 294630844: string (nullable = true)
#  |--  "id_str": "294630844": string (nullable = true)
#  |--  "name": "BR&ON": string (nullable = true)
#  |--  "screen_name": "broux73": string (nullable = true)
#  |--  "location": "Northern Drakensberg \ud83c\uddff\ud83c\udde6\ud83c\udfde\ud83c\udfd5\ufe0f": string (nullable = true)
#  |--  "description": "Don't just stand there: string (nullable = true)
#  |--  follow me                                                            |\n\ud83c\udfd4\ufe0f\ud83c\udfd5\ufe0f\u26fa\ud83c\udf04\ud83c\udfde\ufe0f\ud83c\udf3f\ud83c\udfd4\u26f0": string (nullable = true)
#  |--  "url": null85: string (nullable = true)
#  |--  "entities": {"description": {"urls": []}}86: string (nullable = true)
#  |--  "protected": false87: string (nullable = true)
#  |--  "followers_count": 311: string (nullable = true)
#  |--  "friends_count": 524: string (nullable = true)
#  |--  "listed_count": 3: string (nullable = true)
#  |--  "created_at": "Sat May 07 13:57:02 +0000 2011": string (nullable = true)
#  |--  "favourites_count": 26933: string (nullable = true)
#  |--  "utc_offset": null93: string (nullable = true)
#  |--  "time_zone": null94: string (nullable = true)
#  |--  "geo_enabled": true95: string (nullable = true)
#  |--  "verified": false96: string (nullable = true)
#  |--  "statuses_count": 8630: string (nullable = true)
#  |--  "lang": null98: string (nullable = true)
#  |--  "contributors_enabled": false99: string (nullable = true)
#  |--  "is_translator": false100: string (nullable = true)
#  |--  "is_translation_enabled": false101: string (nullable = true)
#  |--  "profile_background_color": "709397": string (nullable = true)
#  |--  "profile_background_image_url": "http://abs.twimg.com/images/themes/theme6/bg.gif": string (nullable = true)
#  |--  "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme6/bg.gif": string (nullable = true)
#  |--  "profile_background_tile": false105: string (nullable = true)
#  |--  "profile_image_url": "http://pbs.twimg.com/profile_images/1248400674175324160/7ur1k_lb_normal.jpg": string (nullable = true)
#  |--  "profile_image_url_https": "https://pbs.twimg.com/profile_images/1248400674175324160/7ur1k_lb_normal.jpg": string (nullable = true)
#  |--  "profile_banner_url": "https://pbs.twimg.com/profile_banners/294630844/1586701202": string (nullable = true)
#  |--  "profile_link_color": "00FF00": string (nullable = true)
#  |--  "profile_sidebar_border_color": "86A4A6": string (nullable = true)
#  |--  "profile_sidebar_fill_color": "A0C5C7": string (nullable = true)
#  |--  "profile_text_color": "333333"112: string (nullable = true)
#  |--  "profile_use_background_image": true113: string (nullable = true)
#  |--  "has_extended_profile": true: string (nullable = true)
#  |--  "default_profile": false: string (nullable = true)
#  |--  "default_profile_image": false116: string (nullable = true)
#  |--  "following": false117: string (nullable = true)
#  |--  "follow_request_sent": false118: string (nullable = true)
#  |--  "notifications": false119: string (nullable = true)
#  |--  "translator_type": "none"}120: string (nullable = true)
#  |--  "geo": null121: string (nullable = true)
#  |--  "coordinates": null122: string (nullable = true)
#  |--  "place": null123: string (nullable = true)
#  |--  "contributors": null124: string (nullable = true)
#  |--  "retweeted_status": {"created_at": "Fri May 29 08:34:41 +0000 2020": string (nullable = true)
#  |--  "id": 1266286830116200448: string (nullable = true)
#  |--  "id_str": "1266286830116200448": string (nullable = true)
#  |--  "full_text": "#MyBeautifulAfrica....\u2764\nAardwolf.. https://t.co/9C7MjkQaIp": string (nullable = true)
#  |--  "truncated": false129: string (nullable = true)
#  |--  "display_text_range": [0130: string (nullable = true)
#  |--  34]: string (nullable = true)
#  |--  "entities": {"hashtags": [{"text": "MyBeautifulAfrica"132: string (nullable = true)
#  |--  "indices": [0: string (nullable = true)
#  |--  18]}]: string (nullable = true)
#  |--  "symbols": []135: string (nullable = true)
#  |--  "user_mentions": []: string (nullable = true)
#  |--  "urls": []137: string (nullable = true)
#  |--  "media": [{"id": 1266286817315176450138: string (nullable = true)
#  |--  "id_str": "1266286817315176450"139: string (nullable = true)
#  |--  "indices": [35140: string (nullable = true)
#  |--  58]141: string (nullable = true)
#  |--  "media_url": "http://pbs.twimg.com/media/EZLBJrnUwAI9IbT.jpg"142: string (nullable = true)
#  |--  "media_url_https": "https://pbs.twimg.com/media/EZLBJrnUwAI9IbT.jpg"143: string (nullable = true)
#  |--  "url": "https://t.co/9C7MjkQaIp"144: string (nullable = true)
#  |--  "display_url": "pic.twitter.com/9C7MjkQaIp"145: string (nullable = true)
#  |--  "expanded_url": "https://twitter.com/Desiree_Laverne/status/1266286830116200448/photo/1"146: string (nullable = true)
#  |--  "type": "photo"147: string (nullable = true)
#  |--  "sizes": {"thumb": {"w": 150148: string (nullable = true)
#  |--  "h": 150149: string (nullable = true)
#  |--  "resize": "crop"}150: string (nullable = true)
#  |--  "large": {"w": 564151: string (nullable = true)
#  |--  "h": 435152: string (nullable = true)
#  |--  "resize": "fit"}153: string (nullable = true)
#  |--  "small": {"w": 564154: string (nullable = true)
#  |--  "h": 435155: string (nullable = true)
#  |--  "resize": "fit"}156: string (nullable = true)
#  |--  "medium": {"w": 564157: string (nullable = true)
#  |--  "h": 435158: string (nullable = true)
#  |--  "resize": "fit"}}}]}159: string (nullable = true)
#  |--  "extended_entities": {"media": [{"id": 1266286817315176450160: string (nullable = true)
#  |--  "id_str": "1266286817315176450"161: string (nullable = true)
#  |--  "indices": [35162: string (nullable = true)
#  |--  58]163: string (nullable = true)
#  |--  "media_url": "http://pbs.twimg.com/media/EZLBJrnUwAI9IbT.jpg"164: string (nullable = true)
#  |--  "media_url_https": "https://pbs.twimg.com/media/EZLBJrnUwAI9IbT.jpg"165: string (nullable = true)
#  |--  "url": "https://t.co/9C7MjkQaIp"166: string (nullable = true)
#  |--  "display_url": "pic.twitter.com/9C7MjkQaIp"167: string (nullable = true)
#  |--  "expanded_url": "https://twitter.com/Desiree_Laverne/status/1266286830116200448/photo/1"168: string (nullable = true)
#  |--  "type": "photo"169: string (nullable = true)
#  |--  "sizes": {"thumb": {"w": 150170: string (nullable = true)
#  |--  "h": 150171: string (nullable = true)
#  |--  "resize": "crop"}172: string (nullable = true)
#  |--  "large": {"w": 564173: string (nullable = true)
#  |--  "h": 435174: string (nullable = true)
#  |--  "resize": "fit"}175: string (nullable = true)
#  |--  "small": {"w": 564176: string (nullable = true)
#  |--  "h": 435177: string (nullable = true)
#  |--  "resize": "fit"}178: string (nullable = true)
#  |--  "medium": {"w": 564179: string (nullable = true)
#  |--  "h": 435180: string (nullable = true)
#  |--  "resize": "fit"}}}]}181: string (nullable = true)
#  |--  "metadata": {"iso_language_code": "nl"182: string (nullable = true)
#  |--  "result_type": "recent"}183: string (nullable = true)
#  |--  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>"184: string (nullable = true)
#  |--  "in_reply_to_status_id": null185: string (nullable = true)
#  |--  "in_reply_to_status_id_str": null186: string (nullable = true)
#  |--  "in_reply_to_user_id": null187: string (nullable = true)
#  |--  "in_reply_to_user_id_str": null188: string (nullable = true)
#  |--  "in_reply_to_screen_name": null189: string (nullable = true)
#  |--  "user": {"id": 2314937901: string (nullable = true)
#  |--  "id_str": "2314937901"191: string (nullable = true)
#  |--  "name": "Desiree_Laverne"192: string (nullable = true)
#  |--  "screen_name": "Desiree_Laverne": string (nullable = true)
#  |--  "location": "\u2764\ud83e\udd8f\ud83c\udf3f": string (nullable = true)
#  |--  "description": "\u26d4No Dms\u26d4 \n\n\n#Rangers\u2764 \n\n\nACTIVIST \ud83d\udc9a\u270c\n#Resist\n\n#_1_Bullet_1_Poacher. #BanIvoryTrade. \n#BanRhinoHornTrade. #BanCannedHunting.. \n#GMFER": string (nullable = true)
#  |--  "url": null196: string (nullable = true)
#  |--  "entities": {"description": {"urls": []}}197: string (nullable = true)
#  |--  "protected": false198: string (nullable = true)
#  |--  "followers_count": 7049: string (nullable = true)
#  |--  "friends_count": 4921: string (nullable = true)
#  |--  "listed_count": 175: string (nullable = true)
#  |--  "created_at": "Thu Jan 30 20:56:59 +0000 2014": string (nullable = true)
#  |--  "favourites_count": 159144: string (nullable = true)
#  |--  "utc_offset": null204: string (nullable = true)
#  |--  "time_zone": null205: string (nullable = true)
#  |--  "geo_enabled": true206: string (nullable = true)
#  |--  "verified": false207: string (nullable = true)
#  |--  "statuses_count": 163896: string (nullable = true)
#  |--  "lang": null209: string (nullable = true)
#  |--  "contributors_enabled": false210: string (nullable = true)
#  |--  "is_translator": false211: string (nullable = true)
#  |--  "is_translation_enabled": false212: string (nullable = true)
#  |--  "profile_background_color": "C0DEED": string (nullable = true)
#  |--  "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png": string (nullable = true)
#  |--  "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png": string (nullable = true)
#  |--  "profile_background_tile": false216: string (nullable = true)
#  |--  "profile_image_url": "http://pbs.twimg.com/profile_images/1264906862484492288/iVGLP1O-_normal.jpg": string (nullable = true)
#  |--  "profile_image_url_https": "https://pbs.twimg.com/profile_images/1264906862484492288/iVGLP1O-_normal.jpg": string (nullable = true)
#  |--  "profile_banner_url": "https://pbs.twimg.com/profile_banners/2314937901/1585836860": string (nullable = true)
#  |--  "profile_link_color": "1DA1F2": string (nullable = true)
#  |--  "profile_sidebar_border_color": "C0DEED": string (nullable = true)
#  |--  "profile_sidebar_fill_color": "DDEEF6": string (nullable = true)
#  |--  "profile_text_color": "333333"223: string (nullable = true)
#  |--  "profile_use_background_image": true224: string (nullable = true)
#  |--  "has_extended_profile": false: string (nullable = true)
#  |--  "default_profile": true: string (nullable = true)
#  |--  "default_profile_image": false227: string (nullable = true)
#  |--  "following": false228: string (nullable = true)
#  |--  "follow_request_sent": false229: string (nullable = true)
#  |--  "notifications": false230: string (nullable = true)
#  |--  "translator_type": "none"}231: string (nullable = true)
#  |--  "geo": null232: string (nullable = true)
#  |--  "coordinates": null233: string (nullable = true)
#  |--  "place": null234: string (nullable = true)
#  |--  "contributors": null235: string (nullable = true)
#  |--  "is_quote_status": false236: string (nullable = true)
#  |--  "retweet_count": 4237: string (nullable = true)
#  |--  "favorite_count": 37: string (nullable = true)
#  |--  "favorited": false239: string (nullable = true)
#  |--  "retweeted": false240: string (nullable = true)
#  |--  "possibly_sensitive": false241: string (nullable = true)
#  |--  "lang": "nl"}242: string (nullable = true)
#  |--  "is_quote_status": false243: string (nullable = true)
#  |--  "retweet_count": 4244: string (nullable = true)
#  |--  "favorite_count": 0: string (nullable = true)
#  |--  "favorited": false246: string (nullable = true)
#  |--  "retweeted": false247: string (nullable = true)
#  |--  "possibly_sensitive": false248: string (nullable = true)
#  |--  "lang": "nl"}249: string (nullable = true)

# %%
print(df2.columns[0])
print(df2.columns[1])
# Out:
# _c0
# _c1

# %%
from pyspark.sql.functions import *
